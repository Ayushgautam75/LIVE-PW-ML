# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Student_ID': [101, 102, 103, 104, 105, 106, 107, 108],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah'],
    'Math_Score': [85, 90, 78, 92, 88, 45, 95, 100],  # Numerical (Discrete)
    'Reading_Hours': [5.5, 6.0, 4.2, 7.1, 5.0, 1.0, 8.5, 2.0], # Numerical (Continuous)
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F'], # Categorical (Nominal)
    'Grade_Level': ['Sophomore', 'Junior', 'Freshman', 'Senior', 'Junior', 'Freshman', 'Senior', 'Senior'] # Categorical (Ordinal)
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Student_ID     Name  Math_Score  Reading_Hours Gender Grade_Level
# 0         101    Alice          85            5.5      F   Sophomore
# 1         102      Bob          90            6.0      M      Junior
# 2         103  Charlie          78            4.2      M    Freshman
# 3         104    David          92            7.1      M      Senior
# 4         105      Eva          88            5.0      F      Junior
# 5         106    Frank          45            1.0      M    Freshman
# 6         107    Grace          95            8.5      F      Senior
# 7         108   Hannah         100            2.0      F      Senior

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     8 non-null      int64
#  1   Name           8 non-null      object
#  2   Math_Score     8 non-null      int64
#  3   Reading_Hours  8 non-null      float64
#  4   Gender         8 non-null      object
#  5   Grade_Level    8 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 516.0+ bytes

# %%
df.describe()
# Out:
#        Student_ID  Math_Score  Reading_Hours
# count     8.00000    8.000000       8.000000
# mean    104.50000   84.125000       4.912500
# std       2.44949   17.116721       2.492525
# min     101.00000   45.000000       1.000000
# 25%     102.75000   83.250000       3.650000
# 50%     104.50000   89.000000       5.250000
# 75%     106.25000   92.750000       6.275000
# max     108.00000  100.000000       8.500000

# %%
df.describe(include='object')
# Out:
#          Name Gender Grade_Level
# count       8      8           8
# unique      8      2           4
# top     Alice      F      Senior
# freq        1      4           3

# %%
#Q1. Look at the Math_Score in our dataset.
#The lowest score is 45. The highest is 100.
#How does that one low score (45) affect the Mean vs. the Median?

# Q2. Why is Student_ID a numerical variable that we should not calculate the average for?

# Q3. If we changed Grade_Level to numbers (Freshman=1, Senior=4), does it change from Categorical to Numerical?

# %%
challenge_data = {
    'Day': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],
    'Temperature_C': [22, 24, 19, 23, 25, 32, 30],
    'Lemonades_Sold': [10, 12, 8, 11, 15, 50, 48],
    'Flyer_Distributed': ['No', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes']
}
df_lemon = pd.DataFrame(challenge_data)

# %%
# Identify which variable is Numerical Continuous, Numerical Discrete, and Categorical.
# (Temp, Lemonades_Sold, Flyer Distributed)

# Calculate the Mean and Median of Lemonades_Sold

# %%
df_lemon.describe()
# Out:
#        Temperature_C  Lemonades_Sold
# count       7.000000        7.000000
# mean       25.000000       22.000000
# std         4.546061       18.574176
# min        19.000000        8.000000
# 25%        22.500000       10.500000
# 50%        24.000000       12.000000
# 75%        27.500000       31.500000
# max        32.000000       50.000000

# %%
# Compare the Mean and Median. Why are they different? Which day is responsible for this difference?
# Saturday

# Use Python to find the unique values in the Flyer_Distributed column.
df_lemon.describe(include='object')
# Out:
#         Day Flyer_Distributed
# count     7                 7
# unique    7                 2
# top     Mon               Yes
# freq      1                 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Department': ['Sales', 'IT', 'IT', 'HR', 'Sales', 'Sales', 'IT', 'HR', 'Sales', 'IT'],
    'Age': [25, 30, 45, 22, 28, 35, 40, 50, 26, 29],
    'Salary_k': [50, 120, 125, 45, 52, 58, 118, 48, 51, 122], # k means thousands
    'Experience_Yrs': [1, 5, 10, 1, 2, 4, 8, 20, 1, 5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Department  Age  Salary_k  Experience_Yrs
# 0      Sales   25        50               1
# 1         IT   30       120               5
# 2         IT   45       125              10
# 3         HR   22        45               1
# 4      Sales   28        52               2
# 5      Sales   35        58               4
# 6         IT   40       118               8
# 7         HR   50        48              20
# 8      Sales   26        51               1
# 9         IT   29       122               5

# %%
sns.histplot(df['Salary_k'], kde=True, bins=20)
plt.title("Histogram of Salaries")
# Out:
# Text(0.5, 1.0, 'Histogram of Salaries')

# %%
sns.boxplot(x=df['Age'])
plt.title("Boxplot of Age")
# Out:
# Text(0.5, 1.0, 'Boxplot of Age')

# %%
df.describe()
# Out:
#              Age    Salary_k  Experience_Yrs
# count  10.000000   10.000000       10.000000
# mean   33.000000   78.900000        5.700000
# std     9.249625   36.634683        5.888784
# min    22.000000   45.000000        1.000000
# 25%    26.500000   50.250000        1.250000
# 50%    29.500000   55.000000        4.500000
# 75%    38.750000  119.500000        7.250000
# max    50.000000  125.000000       20.000000

# %%
# If you have a dataset of "Housing Prices" and the Mean is $500k
# but the Median is $350k, is the data Right Skewed or Left Skewed?

# %%
# Why do we care about outliers?
# If we are calculating the average (mean) salary to budget for next year,
# should we remove the CEO's salary (the outlier) or keep it?

# %%
battery_data = {
    'Phone_ID': range(1, 16),
    'Battery_Hours': [10, 11, 10, 12, 11, 10, 13, 12, 11, 10, 4, 25, 11, 12, 10]
}
df_battery = pd.DataFrame(battery_data)

# %%
df_battery
# Out:
#     Phone_ID  Battery_Hours
# 0          1             10
# 1          2             11
# 2          3             10
# 3          4             12
# 4          5             11
# 5          6             10
# 6          7             13
# 7          8             12
# 8          9             11
# 9         10             10
# 10        11              4
# 11        12             25
# 12        13             11
# 13        14             12
# 14        15             10

# %%
 # Calculate the Mean and the Median of Battery_Hours.
 df_battery.describe()
# Out:
#         Phone_ID  Battery_Hours
# count  15.000000      15.000000
# mean    8.000000      11.466667
# std     4.472136       4.257207
# min     1.000000       4.000000
# 25%     4.500000      10.000000
# 50%     8.000000      11.000000
# 75%    11.500000      12.000000
# max    15.000000      25.000000

# %%
# Create a Boxplot for Battery_Hours.
sns.boxplot(x = df_battery['Battery_Hours'])
plt.title('Boxplot of Battery Hours')
plt.show()

# %%
# Identify the Outliers visually from the boxplot. What are the values?
# Interpret: One outlier is very low (4), one is very high (25). In a real manufacturing context, what might these represent?

# %% [markdown]
# # Bivariate Analysis

# %%
# Correlation -> Co Relation

# Strong Positive Correlation -> Ice cream sales vs. Temperature.
#(When temp goes up, sales go way up).

#Strong Negative Correlation -> Sweater sales vs. Temperature.
#(When temp goes up, sales go way down).

# No correlation -> Ice cream sales vs. Stock Market price.
 #(No logical link).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='petal_length', y='sepal_width', data=df)
plt.title('sepal_width vs petal_width')
# Out:
# Text(0.5, 1.0, 'sepal_width vs petal_width')

# %%
# Correlation Matrix or HeatMap

# %%
corr = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()

# %%
sns.heatmap(corr, annot=True) #annotation
# Out:
# <Axes: >

# %%
car_data = {
    'Mileage_k': [10, 20, 30, 40, 50, 60, 70, 80], # in thousands
    'Price_k': [25, 22, 18, 15, 12, 10, 8, 7],    # in thousands
    'Age_Yrs': [1, 2, 3, 4, 5, 6, 7, 8],
    'Brand': ['Toyota', 'Honda', 'Toyota', 'BMW', 'Honda', 'Toyota', 'BMW', 'Honda']
}
df_cars = pd.DataFrame(car_data)

# %%
#Q1. What is the relation between Mileage_k and price_k using a scatter plot
plt.scatter(df_cars['Mileage_k'], df_cars['Price_k'])

# %%
#Q2. What is the correlation value between Mileage_k and price_k ?

# %%
df_cars[['Mileage_k', 'Price_k']].corr()
# Out:
#            Mileage_k   Price_k
# Mileage_k   1.000000 -0.986967
# Price_k    -0.986967  1.000000

# %%
sns.boxplot(x='Price_k', y='Brand', data=df_cars)
# Out:
# <Axes: xlabel='Price_k', ylabel='Brand'>

# %% [markdown]
# # Data Cleaning, Data Preparation and Feature Engineering

# %%
import pandas as pd
import numpy as np

# 'np.nan' creates a missing value
data = {
    'House_ID': [1, 2, 3, 4, 5, 6],
    'Price': [250000, 300000, np.nan, 400000, 150000, 280000],
    'SqFt': [1500, 1800, 2200, 2500, 1000, np.nan],
    'City': ['Austin', 'Dallas', 'Austin', 'Houston', 'Dallas', 'Austin'],
    'Condition': ['Good', 'Excellent', 'Fair', 'Excellent', np.nan, 'Good']
}

df = pd.DataFrame(data)
print("--- Raw Data ---")
df
# Out:
# --- Raw Data ---
#    House_ID     Price    SqFt     City  Condition
# 0         1  250000.0  1500.0   Austin       Good
# 1         2  300000.0  1800.0   Dallas  Excellent
# 2         3       NaN  2200.0   Austin       Fair
# 3         4  400000.0  2500.0  Houston  Excellent
# 4         5  150000.0  1000.0   Dallas        NaN
# 5         6  280000.0     NaN   Austin       Good

# %%
df['Price'] = df['Price'].fillna(df['Price'].median())

# %%
df
# Out:
#    House_ID     Price    SqFt     City  Condition
# 0         1  250000.0  1500.0   Austin       Good
# 1         2  300000.0  1800.0   Dallas  Excellent
# 2         3  280000.0  2200.0   Austin       Fair
# 3         4  400000.0  2500.0  Houston  Excellent
# 4         5  150000.0  1000.0   Dallas        NaN
# 5         6  280000.0     NaN   Austin       Good

# %%
df['SqFt'] = df['SqFt'].fillna(df['SqFt'].median())

# %%
df
# Out:
#    House_ID     Price    SqFt     City  Condition
# 0         1  250000.0  1500.0   Austin       Good
# 1         2  300000.0  1800.0   Dallas  Excellent
# 2         3  280000.0  2200.0   Austin       Fair
# 3         4  400000.0  2500.0  Houston  Excellent
# 4         5  150000.0  1000.0   Dallas        NaN
# 5         6  280000.0  1800.0   Austin       Good

# %%
df['Condition'].mode()[0]
# Out:
# 'Excellent'

# %%
df['Condition'] = df['Condition'].fillna(df['Condition'].mode()[0])

# %%
df
# Out:
#    House_ID     Price    SqFt     City  Condition
# 0         1  250000.0  1500.0   Austin       Good
# 1         2  300000.0  1800.0   Dallas  Excellent
# 2         3  280000.0  2200.0   Austin       Fair
# 3         4  400000.0  2500.0  Houston  Excellent
# 4         5  150000.0  1000.0   Dallas  Excellent
# 5         6  280000.0  1800.0   Austin       Good

# %% [markdown]
# # Encoding

# %%
df_encoded = pd.get_dummies(df, columns=['City'])

# %%
df_encoded
# Out:
#    House_ID     Price    SqFt  Condition  City_Austin  City_Dallas  \
# 0         1  250000.0  1500.0       Good         True        False
# 1         2  300000.0  1800.0  Excellent        False         True
# 2         3  280000.0  2200.0       Fair         True        False
# 3         4  400000.0  2500.0  Excellent        False        False
# 4         5  150000.0  1000.0  Excellent        False         True
# 5         6  280000.0  1800.0       Good         True        False
#
#    City_Houston
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False
# 5         False

# %%
# Feature Engineering -> Create new features from exisiting features
df['Price_per_sqft'] = df['Price']/df['SqFt']

# %%
df
# Out:
#    House_ID     Price    SqFt     City  Condition  Price_per_sqft
# 0         1  250000.0  1500.0   Austin       Good      166.666667
# 1         2  300000.0  1800.0   Dallas  Excellent      166.666667
# 2         3  280000.0  2200.0   Austin       Fair      127.272727
# 3         4  400000.0  2500.0  Houston  Excellent      160.000000
# 4         5  150000.0  1000.0   Dallas  Excellent      150.000000
# 5         6  280000.0  1800.0   Austin       Good      155.555556

# %%
hr_data = {
    'Candidate': ['A', 'B', 'C', 'D', 'E'],
    'Test_Score': [85, 90, np.nan, 75, 88],
    'Experience_Yrs': [2, 5, 3, np.nan, 4],
    'Degree': ['Bachelor', 'Master', 'PhD', 'Bachelor', 'Master']
}
df_hr = pd.DataFrame(hr_data)

# %%
#Your Tasks:

#1. Check for missing values.

#2. Fill missing Test_Score with the Mean.

#3. Fill missing Experience_Yrs with the Median.

#4. Perform Label Encoding on the Degree column manually using a map.

# Map: Bachelor=1, Master=2, PhD=3. (Since PhD > Master > Bachelor, this order matters!).

#5. Create a new feature called Score_Per_Year (Test_Score / Experience_Yrs).

# %%
df_hr.isnull().sum()
# Out:
# Candidate         0
# Test_Score        1
# Experience_Yrs    1
# Degree            0
# dtype: int64

# %%
df_hr['Test_Score'] = df_hr['Test_Score'].fillna(df_hr['Test_Score'].mean())

# %%
df_hr
# Out:
#   Candidate  Test_Score  Experience_Yrs    Degree
# 0         A        85.0             2.0  Bachelor
# 1         B        90.0             5.0    Master
# 2         C        84.5             3.0       PhD
# 3         D        75.0             NaN  Bachelor
# 4         E        88.0             4.0    Master

# %%
df_hr['Experience_Yrs'] = df_hr['Experience_Yrs'].fillna(df_hr['Experience_Yrs'].median())

# %%
df_hr
# Out:
#   Candidate  Test_Score  Experience_Yrs    Degree
# 0         A        85.0             2.0  Bachelor
# 1         B        90.0             5.0    Master
# 2         C        84.5             3.0       PhD
# 3         D        75.0             3.5  Bachelor
# 4         E        88.0             4.0    Master

# %%
df_hr.isnull().sum()
# Out:
# Candidate         0
# Test_Score        0
# Experience_Yrs    0
# Degree            0
# dtype: int64

# %%
degree_map = {'Bachelor': 1, 'Master': 2, 'PhD': 3}
df_hr['Degree_encoded'] = df_hr['Degree'].map(degree_map)

# %%
df_hr
# Out:
#   Candidate  Test_Score  Experience_Yrs    Degree  Degree_encoded
# 0         A        85.0             2.0  Bachelor               1
# 1         B        90.0             5.0    Master               2
# 2         C        84.5             3.0       PhD               3
# 3         D        75.0             3.5  Bachelor               1
# 4         E        88.0             4.0    Master               2

# %%
df_hr['Score_per_year'] = df_hr['Test_Score'] / df_hr['Experience_Yrs']

# %%
df_hr
# Out:
#   Candidate  Test_Score  Experience_Yrs    Degree  Degree_encoded  \
# 0         A        85.0             2.0  Bachelor               1
# 1         B        90.0             5.0    Master               2
# 2         C        84.5             3.0       PhD               3
# 3         D        75.0             3.5  Bachelor               1
# 4         E        88.0             4.0    Master               2
#
#    Score_per_year
# 0       42.500000
# 1       18.000000
# 2       28.166667
# 3       21.428571
# 4       22.000000

# %% [markdown]
# # Titanic Case Study

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset
df = sns.load_dataset('titanic')

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# Univariate Analysis
# Q. How many survived vs how many died
# Countplot , barplot
survival_counts = df['survived'].value_counts(normalize=True)
sns.barplot(x=survival_counts.index, y=survival_counts.values)
plt.xticks([0, 1], ['Died', 'Survived'])
plt.ylabel("Proportion")
plt.title("Survival Proportion")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Countplot of survival
sns.countplot(x='survived', data=df)

# Fix xticks: positions [0,1] with labels ['Died','Survived']
plt.xticks([0, 1], ['Died', 'Survived'])
plt.title("Survival Count")
plt.show()

# %% [markdown]
# #More people died compared to people who survived, almost double.

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#age distribution
sns.histplot(df['age'].dropna(),kde = True) #right
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram of Age (with missing values filled by mean age)
sns.histplot(df['age'].fillna(df['age'].mean()), bins=30, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()  #wrong

# %%
#fare Distribution
sns.histplot(df['fare'].dropna(),kde = True) #right
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# Age: The histogram does look roughly bell-shaped, peaking around 20–30 years old, which makes sense given the demographics of passengers. That little bump at 0–5 years highlights the presence of children onboard.
#
# Fare: The distribution is highly right-skewed. Most tickets were relatively cheap, but a handful of passengers paid extraordinarily high fares — those are the outliers stretching the tail of the distribution.

# %% [markdown]
# #Bivariate Analysis

# %%
#hypothesis: Did gender matter?
#which gender survived more?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Countplot of survival by gender
sns.countplot(x='sex', hue='survived', data=df)

plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["Died", "Survived"])
plt.show()

# %%
survival_rates = df.groupby('sex')['survived'].mean()
print(survival_rates)
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
# Hypothesis: Rich people survived more, 1st class, 3rd class
sns.barplot(x='pclass', y='survived', data = df)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
# Hypothesis: Did age matter in survival?
import seaborn as sns
import matplotlib.pyplot as plt

# Boxplot of age by survival status
sns.boxplot(x='survived', y='age', data=df)

plt.title("Age Distribution by Survival")
plt.xlabel("Survival Status")
plt.ylabel("Age")
plt.xticks([0, 1], ['Died', 'Survived'])
plt.show()

# %% [markdown]
# Observation: Age did not matter that much!

# %%
# Feature engineering
df['family_size'] = df['sibsp'] + df['parch'] + 1

# %%
# Hypothesis: Family size matters
sns.barplot(x='family_size', y='survived', data = df)
# Out:
# <Axes: xlabel='family_size', ylabel='survived'>

# %%
#encoding
df_final = pd.get_dummies(df, columns=['sex'])

# %%
df_final.head()
# Out:
#    survived  pclass   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  22.0      1      0   7.2500        S  Third    man
# 1         1       1  38.0      1      0  71.2833        C  First  woman
# 2         1       3  26.0      0      0   7.9250        S  Third  woman
# 3         1       1  35.0      1      0  53.1000        S  First  woman
# 4         0       3  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  family_size  sex_female  \
# 0        True  NaN  Southampton    no  False            2       False
# 1       False    C    Cherbourg   yes  False            2        True
# 2       False  NaN  Southampton   yes   True            1        True
# 3       False    C  Southampton   yes  False            2        True
# 4        True  NaN  Southampton    no   True            1       False
#
#    sex_male
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
